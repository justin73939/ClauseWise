# %%
import os

# Set the Hugging Face environment variable to avoid symlink creation
os.environ["HF_HUB_DISABLE_SYMLINKS"] = "1"

# Now load the dataset
from datasets import load_dataset

dataset = load_dataset("theatticusproject/cuad", split="train")
print(dataset)
# Out:
# Resolving data files:   0%|          | 0/714 [00:00<?, ?it/s]
# ...
# Exception ignored in: <function tqdm.__del__ at 0x0000021AFFBD2C20>
# Traceback (most recent call last):
#   File "c:\CSCE\CSCE489\ClauseWise\.venv\lib\site-packages\tqdm\std.py", line 1148, in __del__
#     self.close()
#   File "c:\CSCE\CSCE489\ClauseWise\.venv\lib\site-packages\tqdm\notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x0000021AFFBD2C20>
# Traceback (most recent call last):
#   File "c:\CSCE\CSCE489\ClauseWise\.venv\lib\site-packages\tqdm\std.py", line 1148, in __del__
#     self.close()
#   File "c:\CSCE\CSCE489\ClauseWise\.venv\lib\site-packages\tqdm\notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# ...
